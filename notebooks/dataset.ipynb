# %%
from datasets import load_from_disk, load_dataset

# %%
ds = load_from_disk("/data/dataset/ner/instruct_uie_ner/")

# %%
dataset_type_set = set(ds["train"]["dataset"])

# %%
len(dataset_type_set)
# Out:
# 26

# %%
ds["train"][0]
# Out:
# {'sentence': 'Xinhua News Agency , Canberra , August 31st',
#  'entities': [{'name': 'Canberra',
#    'pos': [21, 29],
#    'type': 'geographical social political'},
#   {'name': 'Xinhua News Agency', 'pos': [0, 18], 'type': 'organization'}],
#  'dataset': 'ACE_2004',
#  'types': ['geographical social political',
#   'organization',
#   'person',
#   'location',
#   'facility',
#   'vehicle',
#   'weapon']}

# %%
ds_pile = load_dataset("/data/dataset/ner/Pile_NER_type")
# Out:
# Generating train split: 45889 examples [00:00, 48391.31 examples/s]

# %%
ds_pile["train"][0]
# Out:
# {'id': 'ner_0',
#  'conversations': [{'from': 'human',
# ...

# %%
ds_pile_d = load_dataset("/data/dataset/ner/Pile_NER_definition")
# Out:
# Generating train split: 47671 examples [00:01, 30766.78 examples/s]

# %%
ds_pile_d["train"][0]
# Out:
# {'id': 'ner_gpt_0',
#  'conversations': [{'from': 'human',
# ...
